# %%
from bs4 import BeautifulSoup
import requests
from pprint import pprint
import pandas as pd

# %%
stock_name = "sne"
url = "https://www.google.com/search?sxsrf=ACYBGNQtkXYPC6SXE5vkdc7UIzeSR1Zvug%3A1571498905677&ei=mSurXbD9KKO1ggewmLmQDg&q="+stock_name+"&oq="+stock_name+"&gs_l=psy-ab.3..0i131i67l2j0i131i20i263j0i131i67l2j0i67j0i131j0i67j0l2.10385.10924..11457...0.4..1.515.773.3j5-1......0....1..gws-wiz.......0i71.tPuNF6tNdMY&ved=0ahUKEwjwrabQ0ajlAhWjmuAKHTBMDuIQ4dUDCAs&uact=5"
request = requests.get(url)
soup4 = BeautifulSoup(request.text, 'html.parser')
result = soup4.find_all("div")

# %%
print(soup4)
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
for i in list(range(0,len(result))):
    if result[i].find_all(attrs={'class','mw'}):
        pprint(result[i])

# %%
pprint(result[9])
# Out:
# <div class="KP7LCb"> <div class="bRsWnc"> <div class="N6RWV"> <div class="Pg70bf Uv67qb"> <span class="OXXup">All</span><a class="eZt8xd" href="/search?q=aapl&amp;ie=UTF-8&amp;source=lnms&amp;tbm=nws&amp;sa=X&amp;ved=0ahUKEwipkuqz16jlAhW1VRUIHZ5WD_8Q_AUICCgB">News</a><a class="eZt8xd" href="/search?q=aapl&amp;ie=UTF-8&amp;source=lnms&amp;tbm=bks&amp;sa=X&amp;ved=0ahUKEwipkuqz16jlAhW1VRUIHZ5WD_8Q_AUICSgC">Books</a><a class="eZt8xd" href="/search?q=aapl&amp;ie=UTF-8&amp;source=lnms&amp;tbm=shop&amp;sa=X&amp;ved=0ahUKEwipkuqz16jlAhW1VRUIHZ5WD_8Q_AUICigD">Shopping</a> <a href="/search?q=aapl&amp;ie=UTF-8&amp;source=lnms&amp;tbm=isch&amp;sa=X&amp;ved=0ahUKEwipkuqz16jlAhW1VRUIHZ5WD_8Q_AUICygE">Images</a> <a href="https://maps.google.com/maps?sxsrf=ACYBGNQtkXYPC6SXE5vkdc7UIzeSR1Zvug:1571498905677&amp;q=aapl&amp;uact=5&amp;um=1&amp;ie=UTF-8&amp;sa=X&amp;ved=0ahUKEwipkuqz16jlAhW1VRUIHZ5WD_8Q_AUIDCgF">Maps</a> <a href="/search?q=aapl&amp;ie=UTF-8&amp;source=lnms&amp;tbm=vid&amp;sa=X&amp;ved=0a
# ...

# %%
#the below code will get the html code from yahoo finances
#page for the given stock
# we will be scraping the fallowing data from the page


# Previous Close
# open
# Bid
# Ask
# Day's Range
# 52 week range
# Volume
# average volume 
# Market cap
# Beta (3Y Monthly)
# PE Ratio (TTM)
# EPS (TTM)
# Earnings Date
# Forward Dividend & Yield
# Ex-Dividend Date
# 1y Target Est

# %%
stock_name = "sne"
url = "https://finance.yahoo.com/quote/"+stock_name
request = requests.get(url)
soup4 = BeautifulSoup(request.text, 'html.parser')
result = soup4.find_all("table")

# %%
(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1])
# Out:
# '1,053,367'

# %%
result[0].find_all(attrs={'class','Trsdu(0.3s)'})
# Out:
# [<span class="Trsdu(0.3s)" data-reactid="16">127.96</span>,
#  <span class="Trsdu(0.3s)" data-reactid="21">128.23</span>,
#  <span class="Trsdu(0.3s)" data-reactid="26">125.96 x 800</span>,
#  <span class="Trsdu(0.3s)" data-reactid="31">126.75 x 800</span>,
#  <span class="Trsdu(0.3s)" data-reactid="44">1,575,083</span>,
#  <span class="Trsdu(0.3s)" data-reactid="49">1,933,937</span>]

# %%
str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[0]).split(">")[1]\
.split("<")[0].split("B")[0]
# Out:
# '60.223'

# %%
previous_close_number = float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[0]).split("<")[1].split(">")[1])
previous_close = "Previous Close"

open_number = float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[1]).split("<")[1].split(">")[1])
open_string = "Open"

bid_number = str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[2]).split("<")[1].split(">")[1]
bid = "Bid"

ask_number = str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[3]).split("<")[1].split(">")[1]
ask = "Ask"

# %%
for x in list(range(0,len(result[0].find_all(attrs={'class','Ta(end)'})))):
    print(x, result[0].find_all(attrs={'class','Ta(end)'})[x])
# Out:
# 0 <td class="Ta(end) Fw(600) Lh(14px)" data-reactid="15" data-test="PREV_CLOSE-value"><span class="Trsdu(0.3s)" data-reactid="16">59.21</span></td>
# 1 <td class="Ta(end) Fw(600) Lh(14px)" data-reactid="20" data-test="OPEN-value"><span class="Trsdu(0.3s)" data-reactid="21">59.44</span></td>
# 2 <td class="Ta(end) Fw(600) Lh(14px)" data-reactid="25" data-test="BID-value"><span class="Trsdu(0.3s)" data-reactid="26">59.27 x 800</span></td>
# 3 <td class="Ta(end) Fw(600) Lh(14px)" data-reactid="30" data-test="ASK-value"><span class="Trsdu(0.3s)" data-reactid="31">59.29 x 800</span></td>
# 4 <td class="Ta(end) Fw(600) Lh(14px)" data-reactid="35" data-test="DAYS_RANGE-value">59.11 - 59.57</td>
# 5 <td class="Ta(end) Fw(600) Lh(14px)" data-reactid="39" data-test="FIFTY_TWO_WK_RANGE-value">41.91 - 60.74</td>
# 6 <td class="Ta(end) Fw(600) Lh(14px)" data-reactid="43" data-test="TD_VOLUME-value"><span class="Trsdu(0.3s)" data-reactid="44">342,377</span></td>
# ...

# %%
day_range_str = str(result[0].find_all(attrs={'class','Ta(end)'})[4]).split("<")[1].split(">")[1]
day_range = "Day Range"

# %%
fifty_two_week_range_str = str(result[0].find_all(attrs={'class','Ta(end)'})[5]).split("<")[1].split(">")[1]
fifty_two_week_range_str
# Out:
# '41.91 - 60.74'

# %%
fifty_two_week_range_number = str(result[0].find_all(attrs={'class','Ta(end)'})[5]).split("<")[1].split(">")[1]
fifty_two_week_range = "52 Week Range"

# the purpose of the if statements is to take the comma out of the volume (of the stock) number
# because the comma prevents the number from becoming a float
# it is first checking if there is one comma in the string then 
# checking if there is two string in the volume
# if there is one comma in the string the first if statement will return as true
# if there are two commas in the string then the second if statement will return as true
if float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1]):
    
    volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1])
    
elif float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[2]):
    volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[2])
volume = "Volume"


#the same thing we did for the volume we are going to do for the average volume
# because the comma in the string will prevent it from becoming a float
if float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]):
    
    average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1])
    
elif float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[2]):
    average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[2])
average_volume = "Avg. Volume"

# %%
if float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]):
    
    average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1])
    
elif float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]+
str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[2]):
    average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[2])

# %%
market_cap_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[0])
                          .split("<")[1].split(">")[1].split("B")[0])
market_cap = "Market Cap"

# %%
beta_3y_monthly_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[1])
                               .split("<")[1].split(">")[1])
beta_3y_monthly = "Beta (3Y Monthly)"

# %%
pe_ratio_number = float(str(result[1]
     .find_all(attrs={'class','Trsdu(0.3s)'})[2])
      .split("<")[1].split(">")[1])
pe_ratio = "PE Ratio"

# %%
eps_ttm_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[3])
.split("<")[1].split(">")[1])

eps_ttm = "EPS (TTM)"

# %%
earning_date = str(result[1].find_all\
    (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[4])\
    .split("<")[1].split(">")[1]

# %%
forward_dividend_number = float(str(result[1].find_all\
    (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
    .split("<")[1].split(">")[1]\
    .split(" ")[0])
forward_dividend = "Forward Dividend"

# %%
forward_yeild_number = float(str(result[1].find_all\
    (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
    .split("<")[1].split(">")[1]\
    .split(" ")[1].split("%")[0]\
    .split("(")[1])
forward_yeild = "Forward Yeild"

# %%
ex_dividend_date = str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[4])\
.split("<")[1].split(">")[1]

# %%
one_year_target_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[5])\
.split("<")[1].split(">")[1])

one_year_target = "1 Year Target Est."

# %%
soup4
# Out:
# <!DOCTYPE html>
# ...

# %%
data = pd.read_csv("sp500.csv")

# %%
data
# Out:
#     Symbol                                 Name                  Sector
# 0      MMM                           3M Company             Industrials
# 1      AOS                      A.O. Smith Corp             Industrials
# 2      ABT                  Abbott Laboratories             Health Care
# 3     ABBV                          AbbVie Inc.             Health Care
# 4      ACN                        Accenture plc  Information Technology
# 5     ATVI                  Activision Blizzard  Information Technology
# 6      AYI                    Acuity Brands Inc             Industrials
# 7     ADBE                    Adobe Systems Inc  Information Technology
# 8      AAP                   Advance Auto Parts  Consumer Discretionary
# 9      AMD           Advanced Micro Devices Inc  Information Technology
# 10     AES                             AES Corp               Utilities
# 11     AMG        Affiliated Managers Group Inc              Financials
# ...

# %%
stock_dictionary = []
for stock_name in list(data.Symbol):
    url = "https://finance.yahoo.com/quote/"+stock_name
    request = requests.get(url)
    soup4 = BeautifulSoup(request.text, 'html.parser')
    result = soup4.find_all("table")

    if (str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[0])\
                                  .split("<")[1].split(">")[1]) != "N/A":
        previous_close_number = float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[0])\
                                      .split("<")[1].split(">")[1])
    else:
        previous_close_number = "N/A"

        
        
        
    if (str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[1])\
                        .split("<")[1].split(">")[1]) != "N/A":
        open_number = float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[1])\
                        .split("<")[1].split(">")[1])
    else:
        open_number = "N/A"

     
    
        
    if str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[2])\
    .split("<")[1].split(">")[1]  != "N/A":
        bid_number = str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[2])\
        .split("<")[1].split(">")[1]
    else:
        bid_number = "N/A"

        
        
    
    if str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[3])\
    .split("<")[1].split(">")[1]  != "N/A":
        ask_number = str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[3])\
        .split("<")[1].split(">")[1]
    else:
        ask_number = "N/A"
    
    
    if str(result[0].find_all(attrs={'class','Ta(end)'})[4])\
    .split("<")[1].split(">")[1] != "N/A":
        day_range_str = str(result[0].find_all(attrs={'class','Ta(end)'})[4])\
        .split("<")[1].split(">")[1]
    else:
        day_range_str="N/A"
        
        
    if str(result[0].find_all(attrs=\
    {'class','Ta(end)'})[5]).split("<")[1].split(">")[1]  != "N/A":
        fifty_two_week_range_str = str(result[0].find_all(attrs=\
        {'class','Ta(end)'})[5]).split("<")[1].split(">")[1]
    else:
        fifty_two_week_range_str = "N/A"

    # the purpose of the if statements is to take the comma out of the volume (of the stock) number
    # because the comma prevents the number from becoming a float
    # it is first checking if there is one comma in the string then 
    # checking if there is two string in the volume
    # if there is one comma in the string the first if statement will return as true
    # if there are two commas in the string then the second if statement will return as true
    if float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+\
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1]):

        volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
        str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1])

    elif float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[2]):
        volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
        str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1]+
        str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[2])
    else:
        volume_number = "N/A"



    #the same thing we did for the volume we are going to do for the average volume
    # because the comma in the string will prevent it from becoming a float
    if (str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+\
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1])  != "N/A":

        average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+\
        str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1])

    elif float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+\
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]+\
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[2]):
        average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+\
        str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]+\
        str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[2])
    else:
        average_volume_number = "N/A"

    
    
    
    if (str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[0])
                          .split("<")[1].split(">")[1].split("B")[0]) != "N/A":
        market_cap_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[0])
                            .split("<")[1].split(">")[1].split("B")[0])
    else:
        market_cap_number = "N/A"
        
    
    
    if (str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[1])
                               .split("<")[1].split(">")[1]) != "N/A":
        beta_3y_monthly_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[1])
                                   .split("<")[1].split(">")[1])
    else:
        beta_3y_monthly_number = "N/A"
    
    
    
    
    if (str(result[1]
     .find_all(attrs={'class','Trsdu(0.3s)'})[2])
      .split("<")[1].split(">")[1]) != "N/A":
        pe_ratio_number = float(str(result[1]
         .find_all(attrs={'class','Trsdu(0.3s)'})[2])
          .split("<")[1].split(">")[1])
    else:
        pe_ratio_number = "N/A"
        
        
    if (str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[3])
    .split("<")[1].split(">")[1]) != "N/A":
        eps_ttm_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[3])
        .split("<")[1].split(">")[1])
    else:
        eps_ttm_number = "N/A"
        
        
    if str(result[1].find_all\
    (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[4])\
    .split("<")[1].split(">")[1] != "N/A":
        earning_date = str(result[1].find_all\
        (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[4])\
        .split("<")[1].split(">")[1]
    else:
        earning_date = "N/A"
        
   

    if (str(result[1].find_all\
    (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
    .split("<")[1].split(">")[1]\
    .split(" ")[0]) != "N/A":    
        forward_dividend_number = float(str(result[1].find_all\
        (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
        .split("<")[1].split(">")[1]\
        .split(" ")[0])
    else:
        forward_dividend_number = "N/A"
    
    
    
    if (str(result[1].find_all\
    (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
    .split("<")[1].split(">")[1]\
    .split(" ")[1].split("%")[0]\
    .split("(")[1]) != 'N/A)':
        forward_yeild_number = float(str(result[1].find_all\
        (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
        .split("<")[1].split(">")[1]\
        .split(" ")[1].split("%")[0]\
        .split("(")[1])
    else:
        forward_yeild_number = "N/A"
    
    
    
    if str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[4])\
    .split("<")[1].split(">")[1] != "N/A":
        ex_dividend_date = str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[4])\
        .split("<")[1].split(">")[1]
    else:
        ex_dividend_date = "N/A"
    
    
    
    if (str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[5])\
    .split("<")[1].split(">")[1]) != "N/A":
        one_year_target_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[5])\
        .split("<")[1].split(">")[1])
    else:
        one_year_target_number = "N/A"
    
    stock_dictionary.append({
    "stock_name":stock_name,
    "previous_close":previous_close_number,
    "open":open_number,
    "bid":bid_number,
    "ask":ask_number,
    "day_range":day_range_str,
    "52week_range": fifty_two_week_range_str,
    "volume": volume_number,
    "avg_volume":average_volume_number,
    "market cap": market_cap_number,
    "beta": beta_3y_monthly_number,
    "pe_ratio": pe_ratio_number,
    "eps":eps_ttm_number,
    "earnings_date":earning_date,
    "forward_div":forward_dividend_number,
    "forward_yeild": forward_yeild_number,
    "ex_div_date":ex_dividend_date,
    "1year_target_est":one_year_target_number
    
    })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-307-0bdbfdf5622f> in <module>
#       9                                   .split("<")[1].split(">")[1]) != "N/A":
#      10         previous_close_number = float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[0])\
# ---> 11                                       .split("<")[1].split(">")[1])
#      12     else:
#      13         previous_close_number = "N/A"
#
# ValueError: could not convert string to float: '1,244.41'

# %%
pprint(stock_dictionary)
# Out:
# [{'1year_target_est': 70.4,
#   '52week_range': '41.91 - 60.74',
#   'ask': '59.29 x 800',
#   'avg_volume': 1053.0,
#   'beta': 0.96,
#   'bid': '59.27 x 800',
#   'day_range': '59.11 - 59.57',
#   'earnings_date': 'N/A',
#   'eps': 4.76,
#   'ex_div_date': '2019-03-28',
#   'forward_div': 0.37,
#   'forward_yeild': 0.62,
#   'market cap': 72.176,
#   'open': 59.44,
#   'pe_ratio': 12.47,
#   'previous_close': 59.21,
#   'stock_name': 'MMM',
#   'volume': 342377.0},
#  {'1year_target_est': 70.4,
#   '52week_range': '41.91 - 60.74',
#   'ask': '59.29 x 800',
#   'avg_volume': 1053.0,
#   'beta': 0.96,
#   'bid': '59.27 x 800',
#   'day_range': '59.11 - 59.57',
#   'earnings_date': 'N/A',
#   'eps': 4.76,
#   'ex_div_date': '2019-03-28',
#   'forward_div': 0.37,
#   'forward_yeild': 0.62,
#   'market cap': 72.176,
#   'open': 59.44,
#   'pe_ratio': 12.47,
#   'previous_close': 59.21,
#   'stock_name': 'AOS',
#   'volume': 342377.0},
#  {'1year_target_est': 70.4,
# ...

# %%
type("a")
# Out:
# str

# %%
float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
    str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-235-e9ae4c6fd167> in <module>
#       1 float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
# ----> 2     str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1])
#
# IndexError: list index out of range

# %%
len(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})))
# Out:
# 280

# %%
float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-240-7cebde1d3bc9> in <module>
# ----> 1 float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1])
#
# IndexError: list index out of range

# %%
stock_name
# Out:
# 'AET'

# %%
result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]
# Out:
# <span class="Trsdu(0.3s)" data-reactid="35">N/A</span>

# %%
stock_dictionary = {}
for stock_name in list(data.Symbol):
    
    url = "https://finance.yahoo.com/quote/"+stock_name
    request = requests.get(url)
    soup4 = BeautifulSoup(request.text, 'html.parser')
    result = soup4.find_all("table")
    if result != []:
        
        try:
            previous_close_number = float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[0])\
                                              .split("<")[1].split(">")[1])
        except ValueError:

            previous_close_number = "N/A"
            
        except IndexError:
            previous_close_number = "N/A"




        try:
            open_number = float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[1])\
                                .split("<")[1].split(">")[1])
        except ValueError:
            open_number = "N/A"
        except IndexError:
            open_number = "N/A"



        try:
            bid_number = str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[2])\
                .split("<")[1].split(">")[1]
        except IndexError:
            bid_number = "N/A"
  

        try:
            ask_number = str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[3])\
                .split("<")[1].split(">")[1]
        except IndexError:
            ask_number = "N/A"


        try:
            day_range_str = str(result[0].find_all(attrs={'class','Ta(end)'})[4])\
                .split("<")[1].split(">")[1]
        except IndexError: 
            day_range_str = "N/A"



        fifty_two_week_range_str = str(result[0].find_all(attrs=\
            {'class','Ta(end)'})[5]).split("<")[1].split(">")[1]


        # the purpose of the if statements is to take the comma out of the volume (of the stock) number
        # because the comma prevents the number from becoming a float
        # it is first checking if there is one comma in the string then 
        # checking if there is two string in the volume
        # if there is one comma in the string the first if statement will return as true
        # if there are two commas in the string then the second if statement will return as true

        try:
            volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
                str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1])
        except IndexError:
            volume_number = "N/A"

          #volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+
    #         str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[1]+
    #         str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[2])




        #the same thing we did for the volume we are going to do for the average volume
        # because the comma in the string will prevent it from becoming a float


    #         average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[0]+\
    #         str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1])

        try:
            average_volume_number =float(str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[4]).split("<")[1].split(">")[1].split(",")[0]+\
                str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[1]+\
                str(result[0].find_all(attrs={'class','Trsdu(0.3s)'})[5]).split("<")[1].split(">")[1].split(",")[2])
        except IndexError:
            average_volume_number = "N/A"




        try:
            market_cap_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[0])\
                                    .split("<")[1].split(">")[1].split("B")[0])
        except ValueError:
            market_cap_number = "N/A"
        except IndexError:
            market_cap_number = "N/A"



        try:
            beta_3y_monthly_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[1])\
                                           .split("<")[1].split(">")[1])
        except ValueError:
            beta_3y_monthly_number = "N/A"
        except IndexError:
            beta_3y_monthly_number = "N/A"


        try:
            pe_ratio_number = float(str(result[1]\
                 .find_all(attrs={'class','Trsdu(0.3s)'})[2])\
                  .split("<")[1].split(">")[1])
        except ValueError:
            pe_ratio_number = "N/A"
        except IndexError:
            pe_ratio_number = "N/A"



        try:
            eps_ttm_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[3])
                .split("<")[1].split(">")[1])
        except ValueError:
            eps_ttm_number = "N/A"
        except IndexError:
            eps_ttm_number = "N/A"            


        try:
            earning_date = str(result[1].find_all\
                (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[4])\
                .split("<")[1].split(">")[1]
        except IndexError:
            earning_date = "N/A"




        try:
            forward_dividend_number = float(str(result[1].find_all\
                (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
                .split("<")[1].split(">")[1]\
                .split(" ")[0])
        except ValueError:
            forward_dividend_number = "N/A"
        except IndexError:
            forward_dividend_number = "N/A"





#         try:
#             forward_yeild_number = float(str(result[1].find_all\
#                 (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
#                 .split("<")[1].split(">")[1]\
#                 .split(" ")[1].split("%")[0]\
#                 .split("(")[1])
#         except ValueError:
#             forward_yeild_number = "N/A"




        ex_dividend_date = str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[4])\
            .split("<")[1].split(">")[1]




        try:
            one_year_target_number = float(str(result[1].find_all(attrs={'class','Trsdu(0.3s)'})[5])\
                .split("<")[1].split(">")[1])
        except ValueError:
            one_year_target_number = "N/A"

        stock_dictionary.update({stock_name:{
        "stock_name":stock_name,
        "previous_close":previous_close_number,
        "open":open_number,
        "bid":bid_number,
        "ask":ask_number,
        "day_range":day_range_str,
        "52week_range": fifty_two_week_range_str,
        "volume": volume_number,
        "avg_volume":average_volume_number,
        "market cap": market_cap_number,
        "beta": beta_3y_monthly_number,
        "pe_ratio": pe_ratio_number,
        "eps":eps_ttm_number,
        "earnings_date":earning_date,
        "forward_div":forward_dividend_number,
        "forward_yeild": forward_yeild_number,
        "ex_div_date":ex_dividend_date,
        "1year_target_est":one_year_target_number

        }})

# %%
stock_dictionary
# Out:
# [{'stock_name': 'MMM',
#   'previous_close': 163.1,
#   'open': 165.47,
#   'bid': '165.56 x 1000',
#   'ask': '165.79 x 800',
#   'day_range': '164.76 - 166.15',
#   '52week_range': '150.58 - 219.75',
#   'volume': 1949.0,
#   'avg_volume': 1855778.0,
#   'market cap': 96.262,
#   'beta': 1.28,
#   'pe_ratio': 19.97,
#   'eps': 8.31,
#   'earnings_date': '',
#   'forward_div': 5.76,
#   'forward_yeild': 1.84,
#   'ex_div_date': '2019-08-15',
#   '1year_target_est': 172.0},
#  {'stock_name': 'AOS',
#   'previous_close': 51.01,
#   'open': 51.41,
#   'bid': '51.01 x 800',
#   'ask': '51.10 x 1200',
#   'day_range': '50.82 - 51.78',
#   '52week_range': '40.34 - 56.66',
#   'volume': 1423.0,
#   'avg_volume': 1681229.0,
#   'market cap': 8.567,
#   'beta': 1.67,
#   'pe_ratio': 20.51,
#   'eps': 2.49,
#   'earnings_date': '',
#   'forward_div': 0.96,
#   'forward_yeild': 1.84,
#   'ex_div_date': '2019-10-30',
#   '1year_target_est': 52.17},
#  {'stock_name': 'ABT',
# ...

# %%
str(result[1].find_all\
                (attrs={'class',"Ta(end) Fw(600) Lh(14px)"})[5])\
                .split("<")[2]
# Out:
# 'span class="Trsdu(0.3s)" data-reactid="80">N/A'

# %%
stock_name
# Out:
# 'TMK'

# %%
(result[0].find_all(attrs={'class','Trsdu(0.3s)'}))
# Out:
# []

# %%
result[0].find_all(attrs={'class','Trsdu(0.3s)'})
# Out:
# []

# %%
url = "https://web.archive.org/web/20170104214153/https://finance.yahoo.com/quote/aapl"
